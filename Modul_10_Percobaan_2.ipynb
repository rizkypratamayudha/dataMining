# %% [markdown]
# <a href="https://colab.research.google.com/github/rizkypratamayudha/dataMining/blob/main/Modul_10_Percobaan_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import library

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Siapkan data

# %%
X = np.array([[1, 2], [1, 4], [1, 0],
              [4, 2], [4, 4], [4, 0],
              [10, 2], [10, 4], [10, 0]])

# %% [markdown]
# Menghitung WCSS

# %%
wcss = []
for i in range(1, 10):
  kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
  kmeans.fit(X)
  wcss.append(kmeans.inertia_)

# %% [markdown]
# Plot WCSS

# %%
plt.plot(range(1, 10), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
